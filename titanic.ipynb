# %%
import pandas as pd 
df = pd.read_csv('E:\prep\ml\dev\DescionTreeZ&RandomForest\survivor.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(df.Survived,df.SibSp).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
pd.crosstab(df.Survived,df.Parch).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
pd.crosstab(df.Survived,df.Embarked).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
df1 = df.drop(['PassengerId','Name','Survived','Ticket','Fare','Cabin', 'Embarked'],axis=1)

target = df['Survived']

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1         0       3                Braund, Mr. Owen Harris
# 4              5         0       3               Allen, Mr. William Henry
# 5              6         0       3                       Moran, Mr. James
# 6              7         0       1                McCarthy, Mr. Timothy J
# 7              8         0       3         Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                    ...
# 179          180         0       3                    Leonard, Mr. Lionel
# 180          181         0       3           Sage, Miss. Constance Gladys
# 181          182         0       2                       Pernot, Mr. Rene
# 182          183         0       3  Asplund, Master. Clarence Gustaf Hugo
# 185          186         0       1                  Rood, Mr. Hugh Roscoe
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
mising = inputs[inputs['Age'].isnull()]

# %%
mising
# Out:
#      Pclass     Sex  Age  SibSp  Parch
# 5         3    male  NaN      0      0
# 17        2    male  NaN      0      0
# 19        3  female  NaN      0      0
# 26        3    male  NaN      0      0
# 28        3  female  NaN      0      0
# 29        3    male  NaN      0      0
# 31        1  female  NaN      1      0
# 32        3  female  NaN      0      0
# 36        3    male  NaN      0      0
# 42        3    male  NaN      0      0
# 45        3    male  NaN      0      0
# 46        3    male  NaN      1      0
# 47        3  female  NaN      0      0
# 48        3    male  NaN      2      0
# 55        1    male  NaN      0      0
# 64        1    male  NaN      0      0
# 65        3    male  NaN      1      1
# 76        3    male  NaN      0      0
# 77        3    male  NaN      0      0
# 82        3  female  NaN      0      0
# 87        3    male  NaN      0      0
# 95        3    male  NaN      0      0
# 101       3    male  NaN      0      0
# ...

# %%
extractor = inputs.dropna()

# %%
extractor.head(15)
# Out:
#     Pclass     Sex   Age  SibSp  Parch
# 0        3    male  22.0      1      0
# 1        1  female  38.0      1      0
# 2        3  female  26.0      0      0
# 3        1  female  35.0      1      0
# 4        3    male  35.0      0      0
# 6        1    male  54.0      0      0
# 7        3    male   2.0      3      1
# 8        3  female  27.0      0      2
# 9        2  female  14.0      1      0
# 10       3  female   4.0      1      1
# 11       1  female  58.0      0      0
# 12       3    male  20.0      0      0
# 13       3    male  39.0      1      5
# 14       3  female  14.0      0      0
# 15       2  female  55.0      0      0
